# %% [markdown]
# <a href="https://colab.research.google.com/github/ppereiracampoverde/Advanced-Topics-in-Data-Analysis-Big-Data-Data-Mining-Cloud-Computing/blob/main/eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loading Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/ppereiracampoverde/Advanced-Topics-in-Data-Analysis-Big-Data-Data-Mining-Cloud-Computing/refs/heads/main/exercise_data.csv"
data= pd.read_csv(url)
data.head()
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  01-12-2020    110       130     409.1
# 1        60  02-12-2020    117       145     479.0
# 2        60  03-12-2020    103       135     340.0
# 3        45  04-12-2020    109       175     282.4
# 4        45  05-12-2020    117       148     406.0

# %%
#To read the last 5 rows
data.tail(10)
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 22        45          NaN    100       119     282.0
# 23        60   23-12-2020    130       101     300.0
# 24        45  24-12-2020'    105       132     246.0
# 25        60   25-12-2020    102       126     334.5
# 26        60   26-12-2020    100       120     250.0
# 27        60   27-12-2020     92       118     241.0
# 28        60   28-12-2020    103       132       NaN
# 29        60   29-12-2020    100       132     280.0
# 30        60   30-12-2020    102       129     380.3
# 31        60   31-12-2020     92       115     243.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
data.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
data.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# Duration    0.000
# Date        3.125
# Pulse       0.000
# Maxpulse    0.000
# Calories    6.250
# dtype: float64

# %%
data.shape
# Out:
# (32, 5)

# %% [markdown]
# **Data Reducction**

# %%
#Removing the pulse colomn
#data=data.drop(["Pulse"], axis=1)
#data.head()

# %% [markdown]
# Working with data & time

# %%
from datetime import date,datetime

# %%
print(date.today().year)
print(date.today().month)
print(date.today())
# Out:
# 2025
# 1
# 2025-01-30

# %%
current_time = datetime.now()
print(current_time)
# Out:
# 2025-01-30 01:44:58.680013

# %%
print("Current time:", current_time.strftime("%H:%M:%S"))
# Out:
# Current time: 01:44:58

# %%
#Calculate the difference between Pulse & MaxPulse and store it in a new column "DifferenceOfPulse"
data['DifferenceOfPulse']= data['Maxpulse']-data['Pulse']
data.head()
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories  DifferenceOfPulse
# 0        60  01-12-2020    110       130     409.1                 20
# 1        60  02-12-2020    117       145     479.0                 28
# 2        60  03-12-2020    103       135     340.0                 32
# 3        45  04-12-2020    109       175     282.4                 66
# 4        45  05-12-2020    117       148     406.0                 31

# %%
data.head(20)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories  DifferenceOfPulse
# 0         60  01-12-2020    110       130     409.1                 20
# 1         60  02-12-2020    117       145     479.0                 28
# 2         60  03-12-2020    103       135     340.0                 32
# 3         45  04-12-2020    109       175     282.4                 66
# 4         45  05-12-2020    117       148     406.0                 31
# 5         60  06-12-2020    102       127     300.0                 25
# 6         60  07-12-2020    110       136     374.0                 26
# 7        450  08-12-2020    104       134     253.3                 30
# 8         30  09-12-2020    109       133     195.1                 24
# 9         60  10-12-2020     98       124     269.0                 26
# 10        60  11-12-2020    103       147     329.3                 44
# 11        60  12-12-2020    100       120     250.7                 20
# ...

# %%
data['Calories']=data['Calories'].fillna(data['Calories'].mean())
print("Mean of Maxpulse is:", data['Maxpulse'].mean())
print("Mean of Maxpulse is:", data['Maxpulse'].median())
print("Mean of Maxpulse is:", data['Maxpulse'].mode())
# Out:
# Mean of Maxpulse is: 128.5
# Mean of Maxpulse is: 127.5
# Mean of Maxpulse is: 0    120
# Name: Maxpulse, dtype: int64

# %%
data.head(20)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories  DifferenceOfPulse
# 0         60  01-12-2020    110       130    409.10                 20
# 1         60  02-12-2020    117       145    479.00                 28
# 2         60  03-12-2020    103       135    340.00                 32
# 3         45  04-12-2020    109       175    282.40                 66
# 4         45  05-12-2020    117       148    406.00                 31
# 5         60  06-12-2020    102       127    300.00                 25
# 6         60  07-12-2020    110       136    374.00                 26
# 7        450  08-12-2020    104       134    253.30                 30
# 8         30  09-12-2020    109       133    195.10                 24
# 9         60  10-12-2020     98       124    269.00                 26
# 10        60  11-12-2020    103       147    329.30                 44
# 11        60  12-12-2020    100       120    250.70                 20
# ...

# %%
data.shape
# Out:
# (32, 6)

# %%
data.isnull().sum()
# Out:
# Duration             0
# Date                 1
# Pulse                0
# Maxpulse             0
# Calories             0
# DifferenceOfPulse    0
# dtype: int64

# %%
data_cleaned = data.dropna()
#all the rows of all the columns

# %%
data_cleaned.shape
# Out:
# (31, 6)

# %%
data_cleaned.isnull().sum()
# Out:
# Duration             0
# Date                 0
# Pulse                0
# Maxpulse             0
# Calories             0
# DifferenceOfPulse    0
# dtype: int64

# %%
data_cleaned.shape
# Out:
# (31, 6)

# %%
data=data.dropna(subset=['Calories'])
#delete null rows from calories columns only
print(data.isnull().sum())
# Out:
# Duration             0
# Date                 1
# Pulse                0
# Maxpulse             0
# Calories             0
# DifferenceOfPulse    0
# dtype: int64

# %%
print(data.shape)
# Out:
# (32, 6)

# %%
tempData = pd.DataFrame({
    "Age":[25,30,np.nan,35,40],
    "Salary":[50000,60000,55000,np.nan,65000],
    "City":['New York','San Francisco',np.nan,'Chicago','New York']
})
#Question: Fill the missing values, for age -> use mean, for salary: use median, for city use Mode
tempData
# Out:
#     Age   Salary           City
# 0  25.0  50000.0       New York
# 1  30.0  60000.0  San Francisco
# 2   NaN  55000.0            NaN
# 3  35.0      NaN        Chicago
# 4  40.0  65000.0       New York

# %%
tempData.isnull().sum()
# Out:
# Age       1
# Salary    1
# City      1
# dtype: int64

# %%
tempData['Age'] = tempData['Age'].fillna(tempData['Age'].mean())

# %%
tempData['Salary'] = tempData['Salary'].fillna(tempData['Salary'].median())

# %%
tempData['City'] = tempData['City'].fillna(tempData['City'].mode()[0])

# %%
tempData.isnull().sum()
# Out:
# Age       0
# Salary    0
# City      0
# dtype: int64

# %%
tempData
# Out:
#     Age   Salary           City
# 0  25.0  50000.0       New York
# 1  30.0  60000.0  San Francisco
# 2  32.5  55000.0       New York
# 3  35.0  57500.0        Chicago
# 4  40.0  65000.0       New York

# %%
tempData.plot(kind='line',subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
data.plot(kind='line',subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
barData = data[['Pulse','Calories']]
barData.plot(kind='bar')
# Out:
# <Axes: >

# %%
from posixpath import altsep
data.plot(kind='scatter', x='Pulse', y='Maxpulse', alpha=0.6)
plt.title('Pulse vs Maxpulse')
plt.show()

# %%
data.head()
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories  DifferenceOfPulse
# 0        60  01-12-2020    110       130     409.1                 20
# 1        60  02-12-2020    117       145     479.0                 28
# 2        60  03-12-2020    103       135     340.0                 32
# 3        45  04-12-2020    109       175     282.4                 66
# 4        45  05-12-2020    117       148     406.0                 31

# %%
numerical_data = data.drop(columns=['Date'])
numerical_data.head()

# Generate the correlation matrix
correlation_matrix = numerical_data.corr()
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                    Duration     Pulse  Maxpulse  Calories  DifferenceOfPulse
# Duration           1.000000  0.004410  0.049959 -0.113923           0.046612
# Pulse              0.004410  1.000000  0.276583  0.487017          -0.321259
# Maxpulse           0.049959  0.276583  1.000000  0.347419           0.821194
# Calories          -0.113923  0.487017  0.347419  1.000000           0.053162
# DifferenceOfPulse  0.046612 -0.321259  0.821194  0.053162           1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f")

plt.title('Correlation Heatmap')
plt.show()
